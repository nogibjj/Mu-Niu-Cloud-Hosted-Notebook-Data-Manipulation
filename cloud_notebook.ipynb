# %% [markdown]
# <a href="https://colab.research.google.com/drive/1zbk0QNbzwPaGIr5no7xM4qSHt9a8p8W2?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load packages
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and Show Data

# %%
df = pd.read_csv("student_performance.csv")
df.head()
# Out:
#    student_id     name  attendance_rate  final_grade
# 0           1     John               85           80
# 1           2    Sarah               90           87
# 2           3     Alex               78           68
# 3           4  Michael               92           92
# 4           5     Emma               88           85

# %% [markdown]
# ## Data Summary

# %%
# Summarize the data
summary = df.describe()
print(summary)
# Out:
#        student_id  attendance_rate  final_grade
# count    10.00000        10.000000    10.000000
# mean      5.50000        85.600000    80.200000
# std       3.02765         7.441625    10.097304
# min       1.00000        70.000000    62.000000
# 25%       3.25000        82.750000    73.500000
# 50%       5.50000        86.500000    82.500000
# 75%       7.75000        90.750000    87.750000
# max      10.00000        95.000000    92.000000

# %% [markdown]
# ## Data Summary

# %%
num_columns = df.select_dtypes(include='number').columns
df[num_columns].hist(figsize=(12, 8), bins=15)
plt.suptitle('Histograms of Numerical Features')
plt.show()
